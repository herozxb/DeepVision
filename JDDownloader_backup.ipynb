# %%
#! /usr/bin/env python
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import WebDriverWait

import urllib.request
#from urllib2 import urlopen
import time
import os.path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-9c5f9b357d84> in <module>
#       1 #! /usr/bin/env python
# ----> 2 from selenium import webdriver
#       3 from selenium.webdriver.common.keys import Keys
#       4 from selenium.webdriver import ActionChains
#       5 from selenium.webdriver.support.ui import WebDriverWait
#
# ModuleNotFoundError: No module named 'selenium'

# %%
def insert_book(types, install_date,color,working,location,cnx):
    query = "INSERT INTO equipment (type, install_date, color, working, location) " \
            "VALUES(%s,%s,%s,%s,%s)"
    args = (types, install_date,color,working,location)
 
    try:

        cursor = cnx.cursor()
        cursor.execute(query, args)
 
        if cursor.lastrowid:
            print('last insert id', cursor.lastrowid)
        else:
            print('last insert id not found')
 
        cnx.commit()
    except Error as error:
        print(error)
 
    finally:
        cursor.close()

# %%
def insert_books(books):
    query = "INSERT INTO equipment (type, install_date, color, working, location) " \
            "VALUES(%s,%s,%s,%s,%s)"
 
    try:
        cnx = mysql.connector.connect(user='root', password='hero2009', host='127.0.0.1',database='myDB')
 
        cursor = cnx.cursor()
        cursor.executemany(query, books)
 
        cnx.commit()
    except Error as e:
        print('Error:', e)
 
    finally:
        cursor.close()
        cnx.close()

# %%
import mysql.connector

cnx = mysql.connector.connect(user='root', password='hero2009',
                              host='127.0.0.1',
                              database='myDB')
cursor = cnx.cursor()
query = ("SELECT location FROM equipment")
cursor.execute(query)

for (location) in cursor:
    print(location)

cursor.close()
cnx.close()
# Out:
# ('Southwest Corner',)
# ('Northwest Corner',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)
# ('Southwest Corner',)
# ('cursor Corner',)
# ('Sudden Corner',)
# ('close Corner',)
# ('Southwest Sudden',)

# %%
inputs=[("zero", "2016-12-30", "blue", 1, "Southwest Corner"),
       ("one", "2016-12-31", "blue", 1, "cursor Corner"),
       ("two", "2016-12-29", "blue", 1, "Sudden Corner"),
       ("three", "2016-12-28", "blue", 1, "close Corner"),
       ("four", "2016-12-27", "blue", 1, "Southwest Sudden")]


insert_books(inputs)

# %%
def setUp(url):
    #open the website by url
    #! /usr/bin/env python
    #driver = webdriver.Firefox(executable_path="/usr/bin/firefox")
    #driver = webdriver.Chrome("/home/king/Downloads/chromedriver")
    driver = webdriver.Firefox()
    driver.get(url)
    driver.maximize_window()
    return driver

def downloadBigImage(dirver,imageName,dirName):
    print("Start downloading image") 
    
    if downloadBigImage.counter ==0:        
        print("Here is downloading image for the first time ( 1st time )")        
        #Make a dir
        if os.path.isdir("/media/king/DeepVision/JDimage/"+dirName): #/home/king/test/
            print("Here is that the image fold is already have been maden") 
            return True
        else:
            os.makedirs("/media/king/DeepVision/JDimage/"+dirName)
            img = driver.find_element_by_xpath('//div[@id="biger"]/img')
            src = img.get_attribute('src')
            #download file
            imagefile = open("/media/king/DeepVision/JDimage/"+dirName+"/"+imageName,"wb")
            imagefile.write(urllib.request.urlopen(src).read())
            #imagefile.write(urlopen(src).read())
            imagefile.close()
            downloadBigImage.counter += 1
            print("The image is downloaded")
            return None
    
    
    if os.path.isdir("/media/king/DeepVision/JDimage/"+dirName): #/home/king/test/
        print("Here is that the fold is already existed !") 
        downloadBigImage.counter += 1
        pass
    else:
        os.makedirs("/media/king/DeepVision/JDimage/"+dirName) #/home/king/test/
        downloadBigImage.counter += 1
    
    #move mouse
    hoverElem = WebDriverWait(driver,10).until(lambda driver:driver.find_element_by_xpath("//div[@id='biger']"))
    ActionChains(driver).move_to_element(hoverElem).perform()
 

    #click next
    elem = WebDriverWait(driver,10).until(lambda driver:driver.find_element_by_xpath("//a[@class='control next']"))
    elem.click()
    print("Here is that the mouse is clicked!") 
    
    
    
    #download image
    img = driver.find_element_by_xpath('//div[@id="biger"]/img')
    src = img.get_attribute('src')

    imagefile = open("/media/king/DeepVision/JDimage/"+dirName+"/"+imageName,"wb") #/home/king/test/
    imagefile.write(urllib.request.urlopen(src).read())
    #imagefile.write(urlopen(src).read())
    imagefile.close()
    print("The image is downloaded at last!")

    
def insert_image_information(ID_0=0, chinese_name_1='None',price_2=0,saler_3='None',support_num_4=0,good_percent_5=0,with_pic_6=0,add_supoort_7=0,good_support_8=0,mid_support_9=0,bad_support_10=0,web_site_11='None',father_12=0,children_13=0,image_0_savepath_14='None',image_0_havefeature_15=0,image_1_savepath_16='None',image_1_havefeature_17=0,image_2_savepath_18='None',image_2_havefeature_19=0,image_3_savepath_20='None',image_3_havefeature_21=0,image_4_savepath_22='None',image_4_havefeature_23=0,image_5_savepath_24='None',image_5_havefeature_25=0,show_imagepath_26='None'):
    query = "INSERT INTO JDImage_information (ID_0, chinese_name_1,price_2,saler_3,support_num_4,good_percent_5,with_pic_6,add_supoort_7,good_support_8,mid_support_9,bad_support_10,web_site_11,father_12,children_13,image_0_savepath_14,image_0_havefeature_15,image_1_savepath_16,image_1_havefeature_17,image_2_savepath_18,image_2_havefeature_19,image_3_savepath_20,image_3_havefeature_21,image_4_savepath_22,image_4_havefeature_23,image_5_savepath_24,image_5_havefeature_25,show_imagepath_26) " \
            "VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    args = (ID_0, chinese_name_1,price_2,saler_3,support_num_4,good_percent_5,with_pic_6,add_supoort_7,good_support_8,mid_support_9,bad_support_10,web_site_11,father_12,children_13,image_0_savepath_14,image_0_havefeature_15,image_1_savepath_16,image_1_havefeature_17,image_2_savepath_18,image_2_havefeature_19,image_3_savepath_20,image_3_havefeature_21,image_4_savepath_22,image_4_havefeature_23,image_5_savepath_24,image_5_havefeature_25,show_imagepath_26)
 
    try:

        cursor = cnx.cursor()
        cursor.execute(query, args)
 
        if cursor.lastrowid:
            print('last insert id', cursor.lastrowid)
        else:
            print('last insert id not found')
 
        cnx.commit()
    #except Error as error:
    #    print(error)
 
    finally:
        cursor.close()

# %%
#mysql part
import mysql.connector

cnx = mysql.connector.connect(user='root', password='hero2009',
                              host='127.0.0.1',
                              database='test_JD_photos')

#insert_image_information()
cursor = cnx.cursor()
query = ("SELECT chinese_name FROM JDImage_mysql")
cursor.execute(query)

for (ID_0) in cursor:
    print(ID_0)

cursor.close()
cnx.close()
# Out:
# ('索尼（SONY） DSC-WX500 数码相机 黑色（1820万有效像素3英寸180度可翻转屏 30倍光学变焦 Wi-Fi分享上传）',)
# ('佳能（Canon）IXUS 190 数码相机 （2000万像素 10倍光学变焦 24mm超广角 支持Wi-Fi和NFC）银色',)
# ('索尼（SONY） DSC-RX100M5 黑卡数码相机 DSC-RX100 V 索尼128G高速卡+BX1电池+LCRX皮套套装',)
# ('索尼（SONY） DSC-HX60 数码相机 黑色（2040万有效像素 30倍光学变焦 24mm广角 Wi-Fi遥控拍摄）',)
# ('佳能（Canon）小型数码相机 2000万像素 卡片机 自拍 照相机 IXUS175银灰色 官方标配',)
# ('徕卡（leica）相机 莱卡 数码相机Q(TYP116)28广角 全画幅 WIFI传输 黑色 官方标配送32G内存卡',)
# ('索尼（SONY） 长焦数码相机/照相机 DSC-H400',)
# ('索尼（SONY） DSC-WX500 数码相机 白色（1820万有效像素3英寸180度可翻转屏 30倍光学变焦 Wi-Fi分享上传）',)
# ('索尼（SONY） DSC-W830 数码相机 黑色（2010万有效像素 8倍光学变焦 25mm广角 全景扫描）',)
# ('索尼（SONY） DSC-RX1RM2 黑卡全画幅 数码相机/照相机 DSC-RX1R II/M2',)
# ('佳能（Canon）PowerShot G3X 数码相机(2020万有效像素 DIGIC6处理器 24-600mm变焦 IS光学防抖)',)
# ('理光（Ricoh）theta sc 360度全景摄像数码相机 白色 VR概念产品',)
# ('徕卡（leica）相机 莱卡 全画幅 数码旁轴相机 M-D（TYP262） 单机身',)
# ('索尼（SONY） 长焦数码相机/照相机 DSC-HX400',)
# ('索尼（SONY） DSC-RX10 Ⅱ 黑卡数码相机 等效24-200mm F2.8 蔡司镜头（WIFI/NFC）',)
# ('卡西欧（CASIO）ZR3600 数码相机 玫红色 （1210万像素 3.0英寸可翻转液晶屏 12倍光学变焦 ）',)
# ('佳能（Canon）IXUS180 数码相机长焦数码相机 WiFi高清相机 家用相机 黑色16G卡套装',)
# ('索尼（SONY） DSC-WX350 数码相机 粉色（1820万有效像素 20倍光学变焦 25mm广角 Wi-Fi遥控拍摄）',)
# ('宝丽来（Polaroid）CUBE+ 运动相机 蓝色 （1440P高清 智能WIFI 124度广角 800万像素 F2.0光圈 内置锂电）',)
# ('徕卡（Leica）SL (typ601) 全画幅无反相机+24-90mm/2.8-4 ASPH镜头 套机',)
# ('富士（FUJIFILM）BLC-X70 原装皮套 咖啡色 X70适用',)
# ('富士（FUJIFILM）BLC-XT10 原装皮套 黑色 X-T10适用',)
# ('卡西欧（CASIO）EX-FR100 数码相机 （1020万像素 镜头机身可分离 ）白色',)
# ('徕卡（Leica）X-U（Typ113）三防数码相机',)
# ('徕卡（Leica）M35mm f/1.4ASPH 镜头(黑色)',)
# ('徕卡（Leica）M（Typ-262)全画幅旁轴数码相机机身 黑色 M240精简版 新M系相机',)
# ('卡西欧（CASIO）EX-TR550 数码相机礼盒版 （1110万像素 21mm广角） 玫红色',)
# ('奥林巴斯（OLYMPUS）CS-47B PEN-F机身保护套 黑色 奥林巴斯原厂真皮机身护套',)
# ('尼康（NIKON） Coolpix A100 便携数码相机（2005万像素 2.7英寸屏 5倍光学变焦 26mm广角）紫色',)
# ('尼康（NIKON） Coolpix A100 便携数码相机（2005万像素 2.7英寸屏 5倍光学变焦 26mm广角）花纹紫',)
# ('徕卡（Leica）SL镜头 VARIO-ELMARIT 24-90/f2.8-4镜头',)
# ('徕卡（Leica）SF 40 闪光灯 机顶闪光灯 外置闪光灯（14624）',)
# ('卡西欧（CASIO）EX-TR600美颜礼盒（TR600枚红色单机+Dior唇膏+Max Factor彩妆+化妆包+化妆盒）',)
# ('卡西欧（CASIO）EX-TR600美颜礼盒（TR600橙色单机+Dior唇膏+Max Factor彩妆+化妆包+化妆盒）',)
# ('朵拉（dooraa）自拍旋转屏美颜相机高清magii Q邂逅绿',)
# ('朵拉（dooraa）自拍旋转屏美颜相机高清 WIFI版初恋粉',)
# ('卡西欧（CASIO）EX-FR200 数码相机 （1195万像素 镜头机身可分离 ）黑色',)
# ('卡西欧（CASIO）EX-TR600美颜礼盒（TR600金色单机+Dior唇膏+Max Factor彩妆+化妆包+化妆盒）',)
# ('卡西欧（CASIO）EX-TR600美颜礼盒（TR600白色单机+Dior唇膏+Max Factor彩妆+化妆包+化妆盒）',)
# ('卡西欧（CASIO）EX-TR600 数码相机 限量礼盒版 定制声波项链 火彩金 自拍神器 美颜相机',)
# ('佳能（Canon）数码相机 照相机 家用相机 卡片相机 IXUS180黑色 官方标配',)
# ('索尼（SONY）靓咔 KW1 卡哇伊 自拍相机 粉色',)
# ('索尼（SONY）靓咔 KW1 卡哇伊 自拍相机 白色',)
# ('索尼（SONY）靓咔 KW1 卡哇伊 自拍相机 浅紫色',)
# ('索尼（SONY）靓咔 KW1 卡哇伊 自拍相机 绿色',)
# ('尼康（Nikon）V3微单套机（10-30mm f/3.5-5.6 PD VR镜头）',)
# ('索尼（SONY） DSC-W830 数码相机 有效像素2010万，光学变焦倍数 8倍 粉色(标配)',)
# ('卡西欧（CASIO）EX-TR600 数码相机/美颜自拍照相机 宝石粉',)
# ('徕卡（leica）X（TYP113) 数码相机 莱卡相机 （18440/18441） 黑色 相机+32G卡+原厂半套+原厂电池',)
# ('徕卡（leica）X（TYP113) 数码相机 莱卡相机 （18440/18441） 黑色 相机+原厂皮套+32G卡+金刚屏',)
# ('徕卡（leica）X（TYP113) 数码相机 莱卡相机 （18440/18441） 黑色 相机+副厂摄影包+32G卡+原厂闪光灯',)
# ('徕卡（leica）X（TYP113) 数码相机 莱卡相机 （18440/18441） 黑色 相机+副厂摄影包+32G卡+金刚屏+原厂电池',)
# ('徕卡（leica）X（TYP113) 数码相机 莱卡相机 （18440/18441） 黑色 相机+包+32G卡+金刚屏+原厂电池+闪光灯',)
# ('佳能（Canon）PowerShot G5X 数码相机 (2020万有效像素 ）',)
# ('佳能（Canon）PowerShot G9X Mark II 数码相机 银色官方标配',)
# ('索尼（SONY）DSC-W810 便携数码相机 卡片机 银色(官方标配)',)
# ('索尼（SONY）DSC-W810 便携数码相机 卡片机 粉色(官方标配)',)
# ('索尼（SONY）DSC-W830 数码相机 粉红色 16G90SD 电池版套装',)
# ('徕卡（leica）相机 莱卡 数码相机 M-P（TYP240）旁轴 全画幅 M9升级版 黑色 机身+24/3.8镜头',)
# ('徕卡（leica）相机 莱卡 数码相机 M-P（TYP240）旁轴 全画幅 M9升级版 银色 机身+24/3.8镜头',)
# ('柯达（Kodak）SL25 镜头式无线数码相机 25倍光学变焦 NFC/WIFI 白色',)
# ('佳能（Canon）PowerShot N2 数码相机 （约1610万像素 8倍光学变焦） 白色官方标配',)
# ('佳能（Canon）PowerShot N2 数码相机 （约1610万像素 8倍光学变焦） 粉色官方标配',)
# ('佳能（Canon）IXUS175/IXUS180 小型数码相机/卡片机 佳能IXUS175银色 套餐一 含SD8G卡',)
# ('佳能（Canon）IXUS175/IXUS180 小型数码相机/卡片机 佳能IXUS175银色 套餐二 含 SD16G',)
# ('佳能（Canon）博秀(PowerShot)系列数码相机 PowerShot SX620 HS 白色',)
# ('建厂',)

# %%
driverMain = setUp("https://list.jd.com/list.html?cat=652,654,831&page=2&trans=1&JL=6_0_0#J_main")
price = driverMain.find_elements_by_xpath('//strong[@class="J_price"]')
for test in price:
    print(test.get_attribute('i'))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
elemName = "https://item.jd.com/"+str(6008133)+".html"
driver = setUp(elemName)
xpathName = '//span[@class="price J-p-' + str(6008133) + '"]'
testName = driver.find_elements_by_xpath(xpathName)
print(testName[0].text)
#print(testName)
# Out:
# 1099.00

# %%
elemName = "https://item.jd.com/"+str(6008133)+".html"
driver = setUp(elemName)
xpathName = '//div[@class="contact fr clearfix"]/div/div/div/a'
testName = driver.find_elements_by_xpath(xpathName)
print(testName[0].text)
# Out:
# 荣耀京东自营旗舰店

# %%
elemName = "https://item.jd.com/"+str(6008133)+".html"
driver = setUp(elemName)
#xpathName = '//div[@id="comment-count"]/a'
#testName = driver.find_elements_by_xpath(xpathName)
#print(testName[0].text)

#xpathName = '//div[@class="comment-percent"]/strong'
#testpercent = driver.find_elements_by_xpath(xpathName)
#print(testpercent[0].text)



#xpathName = "//*[contains(@id,'comment-count')]/a"
#testpercent = driver.find_elements_by_xpath(xpathName)
#print(testpercent[0].text)

#xpathName = '//div[@class="tab-main large"]/ul/li[@class="current"]'
#testpercent = driver.find_elements_by_xpath(xpathName)
#print(testpercent[1].text)
#商品介绍

#xpathName = '//div[@id="comment"]/div[@class="mt"]/h3'
#testpercent = driver.find_elements_by_xpath(xpathName)
#print(testpercent[0].text)
#商品评价
#time.sleep(10)

xpathName = "//*[contains(@class,'comment-percent')]"
testpercent = driver.find_elements_by_xpath(xpathName)
print(testpercent)
# Out:
# []

# %%
elemName = "https://item.jd.com/"+str(2967929)+".html"
driver = setUp(elemName)

img = driver.find_element_by_xpath('//img[@id="spec-img"]')
src = img.get_attribute('src')
imagefile = open("/media/king/DeepVision/JDimage/test.jpg","wb")
imagefile.write(urllib.request.urlopen(src).read())
# Out:
# 118144

# %%
#!/usr/bin/env bash
#open the list of item
driverMain = setUp("https://list.jd.com/list.html?cat=652,654,831&page=2&trans=1&JL=6_0_0#J_main")
i = 0
#find all item's name
testName = driverMain.find_elements_by_xpath('//ul[@class="gl-warp clearfix "]/li/div')
for nameWeb in testName:
    nameNum = nameWeb.get_attribute('data-sku') 
    print(nameNum)
    #jump to each item page
    if nameNum == None:
        continue
    elemName = "http://item.jd.com/bigimage.aspx?id="+str(nameNum)
    
    driver = setUp(elemName)
    i = 0

    #find the condition of end of the loop
    testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
    loopEnd = testEnd.get_attribute('class') 
    name    = testEnd.get_attribute('alt') 
    downloadBigImage.counter =0
    #find the image name
    img = driver.find_element_by_xpath('//div[@id="biger"]/img')
    name    = img.get_attribute('alt') 
    name = name.replace('/', '_')  

    while loopEnd != "control next next-disabled":#
        if True == downloadBigImage(driver,"___"+str(nameNum)+"___"+str(i)+".jpeg",str(nameNum)):
            break
        print(" after download the big image")
        i=i+1
        testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
        loopEnd = testEnd.get_attribute('class') 
    #downloadBigImage.counter =0
    print("Stop Process!!!")
    driver.close()
    
    
    
    
    
    ################################################################################################
    ID_0=nameNum #done
    chinese_name_1=name #done
    price_2=0 #done
    saler_3='None'#done
    support_num_4=0#done
    good_percent_5=0#JS
    with_pic_6=0#JS
    add_supoort_7=0#JS
    good_support_8=0#JS
    mid_support_9=0#JS
    bad_support_10=0#JS
    web_site_11='None'#done
    father_12=0#after donwload
    children_13=0#after donwload
    image_0_savepath_14='None'#done
    image_0_havefeature_15=0#after donwload
    image_1_savepath_16='None'#done
    image_1_havefeature_17=0#after donwload
    image_2_savepath_18='None'#done
    image_2_havefeature_19=0#after donwload
    image_3_savepath_20='None'#done
    image_3_havefeature_21=0#after donwload
    image_4_savepath_22='None'#done
    image_4_havefeature_23=0#after donwload
    image_5_savepath_24='None'#done
    image_5_havefeature_25=0#after donwload
    
    show_imagepath_26='None'#done
    ################################################################################################
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
driverMain.close()

# %%
#!/usr/bin/env bash
#open the list of item
firstPageName = "https://list.jd.com/list.html?cat=652,654,831"
driverfirstPage = setUp(firstPageName)
number = driverfirstPage.find_elements_by_xpath('//span[@class="fp-text"]/i')[0].text

for pageID in range(int(number)):
    onePageName = firstPageName + "&page="+str(pageID)+"&trans=1&JL=6_0_0#J_main"
    driverMain = setUp(onePageName)
    
    
    i = 0
    #find all item's name
    testName = driverMain.find_elements_by_xpath('//ul[@class="gl-warp clearfix "]/li/div')
    for nameWeb in testName:
        nameNum = nameWeb.get_attribute('data-sku') 
        print(nameNum)
        #jump to each item page
        if nameNum == None:
            continue
        elemName = "http://item.jd.com/bigimage.aspx?id="+str(nameNum)

        driver = setUp(elemName)
        i = 0

        #find the condition of end of the loop
        testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
        loopEnd = testEnd.get_attribute('class') 
        name    = testEnd.get_attribute('alt') 
        downloadBigImage.counter =0
        #find the image name
        img = driver.find_element_by_xpath('//div[@id="biger"]/img')
        name    = img.get_attribute('alt') 
        name = name.replace('/', '_')  

        while loopEnd != "control next next-disabled":
            if True == downloadBigImage(driver,name+"___"+str(nameNum)+"___"+str(i)+".jpeg",name):
                break
            print("here after download big image failed!")
            i=i+1
            testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
            loopEnd = testEnd.get_attribute('class') 
        #downloadBigImage.counter =0
        print("Stop Process!!!")
        driver.close()

    driverMain.close()
    
driverfirstPage.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f510650b3847> in <module>()
#       7 for pageID in range(int(number)):
#       8     onePageName = firstPageName + "&page="+str(pageID)+"&trans=1&JL=6_0_0#J_main"
# ----> 9     driverMain = setUp(onePageName)
#      10
#      11
#
# <ipython-input-7-9174d75781bb> in setUp(url)
#       4     #driver = webdriver.Firefox(executable_path="/usr/bin/firefox")
#       5     #driver = webdriver.Chrome("/home/king/Downloads/chromedriver")
# ----> 6     driver = webdriver.Firefox()
#       7     driver.get(url)
#       8     driver.maximize_window()
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, log_path, firefox_options, service_args)
#     150                 service_args=service_args,
#     151                 log_path=log_path)
# --> 152             self.service.start()
#     153
#     154             capabilities.update(options.to_capabilities())
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#     100                 break
#     101             count += 1
# --> 102             time.sleep(1)
#     103             if count == 30:
#     104                 raise WebDriverException("Can not connect to the Service %s" % self.path)
#
# KeyboardInterrupt:

# %%
onePageName = "https://list.jd.com/list.html?cat=652,654,831&page=47&trans=1&JL=6_0_0#J_main"
driverMain = setUp(onePageName)
number = driverMain.find_elements_by_xpath('//span[@class="fp-text"]/i')[0].text
print(number)
# Out:
# 106

# %%
#!/usr/bin/env bash
#open the list of item
firstPageName = "https://list.jd.com/list.html?cat=652,654,831"
driverfirstPage = setUp(firstPageName)
number = driverfirstPage.find_elements_by_xpath('//span[@class="fp-text"]/i')[0].text

for pageID in range(int(number)):
    onePageName = firstPageName + "&page="+str( int(number) + 1 - pageID )+"&trans=1&JL=6_0_0#J_main"
    #https://list.jd.com/list.html?cat=652,654,831&jth=yi#J_main
    #https://list.jd.com/list.html?cat=652,654,831&page=6&trans=1&JL=6_0_0#J_main
    driverMain = setUp(onePageName)
    print(onePageName)
    '''
    i = 0
    #find all item's name
    testName = driverMain.find_elements_by_xpath('//ul[@class="gl-warp clearfix "]/li/div')
    for nameWeb in testName:
        nameNum = nameWeb.get_attribute('data-sku') 
        print(nameNum)
        #jump to each item page
        if nameNum == None:
            continue
        elemName = "http://item.jd.com/bigimage.aspx?id="+str(nameNum)

        driver = setUp(elemName)
        i = 0

        #find the condition of end of the loop
        testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
        loopEnd = testEnd.get_attribute('class') 
        name    = testEnd.get_attribute('alt') 
        downloadBigImage.counter =0
        #find the image name
        img = driver.find_element_by_xpath('//div[@id="biger"]/img')
        name    = img.get_attribute('alt') 
        name = name.replace('/', '_')  

        while loopEnd != "control next next-disabled":
            if True == downloadBigImage(driver,name+"___"+str(nameNum)+"___"+str(i)+".jpeg",name):
                break
            print("here##########################################################")
            i=i+1
            testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
            loopEnd = testEnd.get_attribute('class') 
        #downloadBigImage.counter =0
        print("Stop Process!!!")
        driver.close()
    '''
    time.sleep(5)
    driverMain.close()
    if pageID == 0:
        driverfirstPage.close()
# Out:
# https://list.jd.com/list.html?cat=652,654,831&page=47&trans=1&JL=6_0_0#J_main
# https://list.jd.com/list.html?cat=652,654,831&page=46&trans=1&JL=6_0_0#J_main
# https://list.jd.com/list.html?cat=652,654,831&page=45&trans=1&JL=6_0_0#J_main
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-12-958e86fc7452> in <module>()
#      48     '''
#      49     time.sleep(5)
# ---> 50     driverMain.close()
#      51     if pageID == 0:
#      52         driverfirstPage.close()
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium-2.44.0-py3.5.egg/selenium/webdriver/remote/webdriver.py in close(self)
#     443             driver.close()
#     444         """
# --> 445         self.execute(Command.CLOSE)
#     446
#     447     def quit(self):
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium-2.44.0-py3.5.egg/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     169
#     170         params = self._wrap_value(params)
# --> 171         response = self.command_executor.execute(driver_command, params)
#     172         if response:
#     173             self.error_handler.check_response(response)
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium-2.44.0-py3.5.egg/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     347         path = string.Template(command_info[1]).substitute(params)
#     348         url = '%s%s' % (self._url, path)
# --> 349         return self._request(command_info[0], url, body=data)
#     350
#     351     def _request(self, method, url, body=None):
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium-2.44.0-py3.5.egg/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     378             try:
#     379                 self._conn.request(method, parsed_url.path, body, headers)
# --> 380                 resp = self._conn.getresponse()
#     381             except httplib.HTTPException:
#     382                 self._conn.close()
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/http/client.py in _read_status(self)
#     264             # Presumably, the server closed the connection before
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#     268         try:
#
# RemoteDisconnected: Remote end closed connection without response

# %%
#Test  Program
driver = setUp("http://item.jd.com/bigimage.aspx?id=3133823")#3525270#1957851206#3133823
i = 0
testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
loopEnd = testEnd.get_attribute('class') 
name    = testEnd.get_attribute('alt') 
downloadBigImage.counter =0


img = driver.find_element_by_xpath('//div[@id="biger"]/img')
name    = img.get_attribute('alt') 
name = name.replace('/', '_')  
print(name)
while loopEnd != "control next next-disabled":
    if True == downloadBigImage(driver,name+"__"+str(i)+".jpeg",name):
        break
        
    i=i+1
    print(i)
    testEnd = driver.find_element_by_xpath('//div[@id="biger"]/a[2]')
    loopEnd = testEnd.get_attribute('class') 
    print("here00000000000000000000000000000000000000000000000")
    print(loopEnd)
    
print("Stop Process!!!")
driver.close()
# Out:
# Apple iPhone 7 (A1660) 128G 玫瑰金色 移动联通电信4G手机
# Start downloading image
# Here is downloading image for the first time ( 1st time )
# The image is downloaded
# 1
# here00000000000000000000000000000000000000000000000
# control next
# Start downloading image
# Here is that the fold is already existed !
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-26-fc57062024b2> in <module>()
#      13 print(name)
#      14 while loopEnd != "control next next-disabled":
# ---> 15     if True == downloadBigImage(driver,name+"__"+str(i)+".jpeg",name):
#      16         break
#      17
#
# <ipython-input-6-9174d75781bb> in downloadBigImage(dirver, imageName, dirName)
#      42     #move mouse
#      43     hoverElem = WebDriverWait(driver,10).until(lambda driver:driver.find_element_by_xpath("//div[@id='biger']"))
# ---> 44     ActionChains(driver).move_to_element(hoverElem).perform()
#      45
#      46
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#      82             for action in self._actions:
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      74             if encoded['actions']:
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
#      78     def clear_actions(self):
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# /home/king/anaconda2/envs/py3k/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: POST /session/05069b6f-a446-465a-a650-93d9ae47a70a/actions did not match a known command
